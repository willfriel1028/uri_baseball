# %%
import pandas as pd
import glob

files = glob.glob("hit_logs/**/*.csv", recursive=True)
df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

# %%
del df["Unnamed: 0"]

# %%
df.to_csv("full_hit_data.csv")
