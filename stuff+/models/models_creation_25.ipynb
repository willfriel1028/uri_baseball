# %%
import pandas as pd
import numpy as np
import pickle
from lightgbm import LGBMRegressor

df = pd.read_csv("../full_data.csv")

# %%
pitches = list(df["pitchType"].unique())
lr = ["L", "R"]

features = ['vertApprAngle', 'inducedVertBreak', 'horzBreak', 'horzApprAngle', 'extension', 'relX', 'relZ', 'releaseVelocity', 'spinRate', 'spinDir']
target = "rv"

train = df[df["year"] < 2025]

# %%
def pred(train, features, target, pitch, side):
    
    X_train = train[features]
    y_train = train[target]
    
    model = LGBMRegressor(
        n_estimators=500,
        learning_rate=0.05,
        num_leaves=63,
        min_child_samples=50,
        n_jobs=-1,
        random_state=42
    )
    
    model.fit(X_train, y_train) 

    with open(f'25_{pitch}_{side}.pkl', 'wb') as f:
        pickle.dump(model, f)
    
    print(f"Model for pitch = {pitch}, and side = {side} saved!")

# %%
for pitch in pitches: 
        for side in lr: 
            tr = train[(train["pitchType"] == pitch) & (train["pitcherHand"] == side)]
            if len(tr) > 2300:
                pred(tr, features, target, pitch, side)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 540324, number of used features: 10
# [LightGBM] [Info] Start training from score 0.100638
# Model for pitch = FA, and side = L saved!
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002552 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 1377529, number of used features: 10
# [LightGBM] [Info] Start training from score 0.108521
# Model for pitch = FA, and side = R saved!
# ...
