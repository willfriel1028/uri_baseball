# %%
import pandas as pd
import numpy as np
import pickle
from lightgbm import LGBMRegressor
MODELS_CACHE = {}

# %%
# Read in full csv file
df = pd.read_csv("full_data.csv")

# %%
# Pitch types and sides
pitches = ("FA", "SL", "CH", "CU", "FC", "SI", "FS")
lr = ["L", "R"]

# Features & target
features = ['inducedVertBreak', 'horzBreak', 'extension', 'relX', 'relZ', 'releaseVelocity', 'spinRate']
target = ["rv"]

# Set test year
test = df[df["year"] == 2026]

# %%
# Filter test df so only pitch types we are looking for are included
test = test[test["pitchType"].isin(pitches)]

# %%
# Function that reads in a pitch, loads a pre-trained model, and predicts run value of that pitch
def pred_rv(test, features, target, pitch, side):
    if (pitch, side) not in MODELS_CACHE:
        with open(f'models/26_{pitch}_{side}.pkl', 'rb') as f:
            MODELS_CACHE[(pitch, side)] = pickle.load(f)

    model = MODELS_CACHE[(pitch, side)]
    X_test = test[features]
    predictions = model.predict(X_test) 
    
    return pd.Series(predictions, index=test.index)

# %%
rows = []
i=1

# Loop thru every pitch(row) of the test set and call pred_rv to predict each run value
for index, row in test.iterrows():
    pitch = row["pitchType"]
    side = row["pitcherHand"]

    test = pd.DataFrame([row])
    
    test["xrv"] = float(pred_rv(test, features, target, pitch, side).iloc[0]) 
    rows.append(test)

    # Print a number for every 100,000 pitches
    if i % 100000 == 0:
        print(i)

    i = i+1
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000

# %%
# Concatenate all pitches into one df
new = pd.concat(rows)

# %%
# Group by pitcherId, get mean of relevnt columns
stuff = new.groupby(["pitcherId", "pitchType"]).agg(
    Pitcher = ("Pitcher", "first"),
    year = ("year", "mean"),
    team = ("pitchingTeam", "first"),
    Hand = ("pitcherHand", "first"),
    Count = ("pitchType", "count"),
    RelSpeed = ("releaseVelocity", "mean"),
    IVB = ("inducedVertBreak", "mean"),
    HB = ("horzBreak", "mean"),
    SpinRate = ("spinRate", "mean"),
    RelSide = ("relX", "mean"),
    RelHeight = ("relZ", "mean"),
    Extension = ("extension", "mean"),
    xrv = ("xrv", "mean")
).reset_index()

# %%
stuff = stuff[["Pitcher", "pitcherId", "team", "pitchType", "Hand", "Count", "RelSpeed", "IVB", "HB", "SpinRate", "RelSide", "RelHeight", "Extension", "xrv"]]

# Pitcher must throw at least 25 of a pitch type to qualify
stuff = stuff[stuff["Count"] >= 25]

# %%
stuff = stuff.rename(columns={'pitchType': 'PitchType'})

# %%
stuff[stuff["team"] == "URI"].sort_values("xrv")
# Out:
#               Pitcher   pitcherId team PitchType Hand  Count   RelSpeed  \
# 12300       P. Aikens  1299756340  URI        SL    L    183  72.773770
# 1837       E. Maloney  1085415168  URI        CH    R    105  75.727619
# 2871         A. Jones  1101042688  URI        CU    R     40  76.402500
# 18036       M. Santos  1487988943  URI        SL    R    198  81.849495
# 3230       J. Sabbath  1110853376  URI        SL    R    253  78.682213
# 16040       J. Cullen  1358089441  URI        CU    R     63  76.393651
# 16044       J. Cullen  1358089441  URI        SL    R    102  83.207843
# 4413     L. Lavigueur  1143021056  URI        SL    R    130  78.691538
# 14363      C. Maloney  1336247552  URI        SL    R     65  82.427692
# 10689     J. Kopetski  1269533184  URI        FC    L     66  76.672727
# 2874         A. Jones  1101042688  URI        SL    R     53  83.237736
# 9537       D. Asencio  1241946368  URI        SL    R     37  74.927027
# ...

# %%
# Convert xrv to an above-average stat, resulting in our Stuff+ values for each pitcher/pitch

from scipy import stats

stuff["Stuff+"] = 100 + (-10 * stuff.groupby("PitchType")["xrv"].transform(stats.zscore))
stuff["Stuff+"] = stuff["Stuff+"].round().astype(int)

# %%
stuff.sort_values("Stuff+", ascending=False)
# Out:
#               Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 26547     D. Volantis  1979617275   TEX        CU    L    383  81.376762
# 5097        G. Helsel  1162012672   XAV        FC    L    181  78.374033
# 3598    A. Buczkowski  1123936875   CIN        SL    R    332  81.022590
# 12360        H. Dietz  1301090561   ARK        CU    L    136  80.165441
# 168       D. Hamilton  1008376863  CARK        SI    R     62  90.466129
# ...               ...         ...   ...       ...  ...    ...        ...
# 2317          A. Lyon  1094692864  COFC        CH    R     34  73.467647
# 2782         T. Beard  1100603904   FSU        SL    L    149  84.998658
# 5643    J. Rosenblitt  1164786998   OAK        CU    R     45  68.164444
# 10579      J. Douthat  1266710507   VMI        SI    L     35  81.891429
# 4805   M. Mastroianni  1153408256  DUKE        FC    L     51  76.000000
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# ...

# %%
# Best pitches in country
stuff.sort_values("Stuff+", ascending=False).head(10)
# Out:
#              Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 26547    D. Volantis  1979617275   TEX        CU    L    383  81.376762
# 5097       G. Helsel  1162012672   XAV        FC    L    181  78.374033
# 3598   A. Buczkowski  1123936875   CIN        SL    R    332  81.022590
# 12360       H. Dietz  1301090561   ARK        CU    L    136  80.165441
# 168      D. Hamilton  1008376863  CARK        SI    R     62  90.466129
# 1170       M. Harsch  1065101304  WAKE        SI    R     65  96.141538
# 21330   B. Trosclair  1674977859  NWST        CU    L     29  78.096552
# 10385      R. Hughes  1262528256   TOL        SI    R     42  92.028571
# 12743     B. Purcell  1307080960   FSU        CH    R     93  85.370968
# 7816      D. Jackson  1205651242  UCSB        CH    L    148  76.597973
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 26547 -12.064752   3.326110  2586.378590 -2.091384   6.800522   5.224021
# ...

# %%
stuff[stuff["team"] == "URI"].sort_values("Stuff+", ascending=False)
# Out:
#               Pitcher   pitcherId team PitchType Hand  Count   RelSpeed  \
# 1837       E. Maloney  1085415168  URI        CH    R    105  75.727619
# 12300       P. Aikens  1299756340  URI        SL    L    183  72.773770
# 16041       J. Cullen  1358089441  URI        FA    R    341  91.593548
# 7679    C. Grotyohann  1203468032  URI        FA    R    173  90.732370
# 18034       M. Santos  1487988943  URI        FA    R    192  92.588021
# 18036       M. Santos  1487988943  URI        SL    R    198  81.849495
# 14360      C. Maloney  1336247552  URI        FA    R    110  90.299091
# 2872         A. Jones  1101042688  URI        FA    R    143  89.686014
# 3230       J. Sabbath  1110853376  URI        SL    R    253  78.682213
# 2871         A. Jones  1101042688  URI        CU    R     40  76.402500
# 9538      C. Johnston  1241946624  URI        CH    R    146  80.241096
# 12260        W. Creed  1299086745  URI        FA    L     68  86.657353
# ...

# %%
# Exploring the best of each pitch type nation wide

# %%
stuff[stuff["PitchType"] == "FA"].sort_values("Stuff+", ascending=False).head(10)
# Out:
#              Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 5073        J. Music  1161348114  CAMP        FA    R    212  92.099528
# 4975    B. Frederick  1158279680  TENN        FA    R    319  82.363636
# 7239       R. Marohn  1197348608  NCST        FA    L    381  91.790289
# 20160      S. Garcia  1602557566   LSU        FA    L    157  92.716561
# 24696     J. Barberi  1862463014   FLA        FA    R    260  97.502308
# 7286       S. Matson  1198395392   USC        FA    L    383  90.302611
# 14962       P. Manca  1342167297   FSU        FA    L     84  90.796429
# 17675    S. Sandford  1464054215   FLA        FA    R    222  95.184234
# 13188        C. West  1310862081  CONN        FA    L    529  90.734405
# 19247  J. Nottingham  1557710177   UGA        FA    R    156  95.980769
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 5073   21.347170  13.038208  2209.424528  3.513208   5.965566   5.712736
# ...

# %%
stuff[stuff["PitchType"] == "SL"].sort_values("Stuff+", ascending=False).head(10)
# Out:
#              Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 3598   A. Buczkowski  1123936875   CIN        SL    R    332  81.022590
# 12364       H. Dietz  1301090561   ARK        SL    L    129  85.413178
# 14018       C. Benge  1330701056   LSU        SL    R     32  84.621875
# 4772       C. Stokes  1152980224   FSU        SL    R    162  84.927160
# 13618        M. Yehl  1319280896   WVU        SL    L    253  84.630040
# 22783      K. Graham  1753862210   USA        SL    R     36  82.775000
# 9973        J. Flora  1254299136  UCSB        SL    R    218  85.425229
# 669    M. Brassfield  1038792681   TCU        SL    L    383  84.926893
# 1436       J. Dimino  1078910874   UNF        SL    L     72  83.198611
# 3810      D. Whitney  1128102459  ORST        SL    R    114  86.636842
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 3598   10.767169 -12.430723  2579.635542  5.368976   3.634639   5.293976
# ...

# %%
stuff[stuff["PitchType"] == "CH"].sort_values("Stuff+", ascending=False).head(10)
# Out:
#               Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 12743      B. Purcell  1307080960   FSU        CH    R     93  85.370968
# 7816       D. Jackson  1205651242  UCSB        CH    L    148  76.597973
# 21688     S. Shenosky  1689800810   PSU        CH    R     28  75.114286
# 10225       S. McCabe  1258728572  COFC        CH    R     25  77.088000
# 12040        G. Naess  1296842752    CP        CH    R    274  75.827007
# 25896         C. Sova  1939270667  BGSU        CH    R     88  77.178409
# 8204   R. Featherston  1212946688   ORE        CH    R     72  83.895833
# 6905      J. Mitchell  1194506240  BING        CH    R    135  84.869630
# 19727   C. Chatterton  1584179280   AUB        CH    R    114  75.914912
# 23222     C. Hartsell  1778925046    BC        CH    R     98  80.470408
#
#             IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 12743  4.695699  15.644086  1378.559140  0.355914   6.738710   5.109677
# ...

# %%
stuff[stuff["PitchType"] == "CU"].sort_values("Stuff+", ascending=False).head(10)
# Out:
#             Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 26547   D. Volantis  1979617275   TEX        CU    L    383  81.376762
# 12360      H. Dietz  1301090561   ARK        CU    L    136  80.165441
# 21330  B. Trosclair  1674977859  NWST        CU    L     29  78.096552
# 9469      H. Leffew  1239346432   TEX        CU    L    136  80.859559
# 11007    K. English  1275287609   IND        CU    R     27  83.503704
# 3732     J. Gomberg  1126277376  UNLV        CU    L     27  84.370370
# 16520  M. Stevenson  1386657229   BEL        CU    R     59  76.408475
# 12521     M. Knight  1304692992  MOSU        CU    L    309  77.913916
# 16027   C. Townsend  1357477972  MISS        CU    R    124  82.676613
# 22572     C. Foster  1740630964  MSST        CU    L     58  78.265517
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 26547 -12.064752   3.326110  2586.378590 -2.091384   6.800522   5.224021
# ...

# %%
stuff[stuff["PitchType"] == "FC"].sort_values("Stuff+", ascending=False).head(10)
# Out:
#            Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 5097     G. Helsel  1162012672   XAV        FC    L    181  78.374033
# 15884       H. Han  1348178401   TTU        FC    R     30  79.636667
# 22429     J. Lucas  1734064400  TROY        FC    L     29  77.310345
# 13459       M. Paz  1315747265   LSU        FC    R     30  89.346667
# 11590  D. Pressley  1285478656  WEBB        FC    R     32  82.721875
# 15410    A. Vargas  1342169018  NICH        FC    L    164  87.713415
# 12362     H. Dietz  1301090561   ARK        FC    L    364  85.184890
# 5342      R. White  1162368768   WCU        FC    L     28  79.221429
# 21862    W. Jordan  1698188238   TTU        FC    R     64  80.595313
# 12143  I. Williams  1297495552  OKLA        FC    R     42  89.304762
#
#             IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 5097   7.903867   7.519890  2188.348066 -2.481768   6.627072   5.295028
# ...

# %%
stuff[stuff["PitchType"] == "SI"].sort_values("Stuff+", ascending=False).head(10)
# Out:
#               Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 168       D. Hamilton  1008376863  CARK        SI    R     62  90.466129
# 1170        M. Harsch  1065101304  WAKE        SI    R     65  96.141538
# 10385       R. Hughes  1262528256   TOL        SI    R     42  92.028571
# 26453   C. Van Ameyde  1970680555    ND        SI    R    188  91.592553
# 14326        E. Norby  1335271936   ECU        SI    L     42  91.302381
# 20291        N. Romer  1609880601   SJU        SI    R     63  81.647619
# 7554         K. Hawks  1201847438  MORE        SI    L     32  89.421875
# 22281  C. Appenzeller  1722877754  TENN        SI    L     81  90.393827
# 7581      M. Gosztola  1202396160   ORE        SI    L     62  91.604839
# 18356        N. Toups  1505713358  SELA        SI    L    308  92.798052
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 168    17.624194  17.533871  2455.758065  2.495161   5.132258   5.620968
# ...

# %%
stuff[stuff["PitchType"] == "FS"].sort_values("Stuff+", ascending=False).head(10)
# Out:
#             Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 4370        J. Noot  1142711296   LSU        FS    R     44  87.709091
# 14300   J. Giordano  1334554354  RICH        FS    L     92  76.967391
# 5046   L. Earnhardt  1160764160   WIN        FS    L     87  78.150575
# 3494       L. Kenny  1120804043  UOWG        FS    R     74  82.048649
# 19257      K. Sweum  1558099259  GONZ        FS    L     42  81.533333
# 23440      P. Bauer  1791552299   JMU        FS    R     36  79.286111
# 19769       H. Bond  1586062407  TXAM        FS    L     60  80.478333
# 1019   D. Brousseau  1055997641   BYU        FS    R     54  81.464815
# 7793       O. Marsh  1205184939   BEL        FS    R     53  82.077358
# 6806     B. Fridgen  1191930494  PENN        FS    R     25  80.424000
#
#             IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 4370  -0.156818  16.836364  1514.000000  1.906818   6.159091   4.927273
# ...

# %%
# Save stuff df as a csv
stuff.to_csv("stuff.csv")

# %%
stuff[stuff["Count"] > 200].sort_values("Stuff+", ascending=False)
# Out:
#              Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 26547    D. Volantis  1979617275   TEX        CU    L    383  81.376762
# 3598   A. Buczkowski  1123936875   CIN        SL    R    332  81.022590
# 5073        J. Music  1161348114  CAMP        FA    R    212  92.099528
# 4975    B. Frederick  1158279680  TENN        FA    R    319  82.363636
# 12362       H. Dietz  1301090561   ARK        FC    L    364  85.184890
# ...              ...         ...   ...       ...  ...    ...        ...
# 15579     T. Bourque  1342169568    WM        FC    L    201  84.836816
# 2940      L. Nichols  1104573440    LT        SI    L    320  88.250625
# 22909        L. Doll  1760080732  MRSH        CU    L    225  72.558667
# 5176      E. Sargent  1162067200  UMBC        SL    L    314  75.837898
# 12977       H. Rowan  1310432768    LT        CU    L    226  82.033186
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# ...

# %%
stuff[(stuff["Hand"] == "R") & (stuff["PitchType"] == "FA")].sort_values("Stuff+", ascending=False).head(10)
# Out:
#              Pitcher   pitcherId  team PitchType Hand  Count   RelSpeed  \
# 5073        J. Music  1161348114  CAMP        FA    R    212  92.099528
# 4975    B. Frederick  1158279680  TENN        FA    R    319  82.363636
# 24696     J. Barberi  1862463014   FLA        FA    R    260  97.502308
# 26198       C. Clark  1956935142   USM        FA    R    428  93.192290
# 17675    S. Sandford  1464054215   FLA        FA    R    222  95.184234
# 19247  J. Nottingham  1557710177   UGA        FA    R    156  95.980769
# 4230         J. Raab  1139725824  GTWN        FA    R    252  92.604762
# 12745     B. Purcell  1307080960   FSU        FA    R    279  92.278136
# 3375       C. Howard  1116162816   TEX        FA    R     97  94.542268
# 21716    L. ODonnell  1691990270   USF        FA    R     98  95.098980
#
#              IVB         HB     SpinRate   RelSide  RelHeight  Extension  \
# 5073   21.347170  13.038208  2209.424528  3.513208   5.965566   5.712736
# ...

# %%
import pandas as pd
import numpy as np
stuff = pd.read_csv("stuff.csv")
pitches = list(stuff["PitchType"].unique())

# %%
# Converting stuff csv to a leaderboard format, where each pitcher/pitch type is in one row

rows = []
ids = list(stuff["pitcherId"].unique())

for i in ids:
    x = stuff[stuff["pitcherId"] == i]
    dx = {}
    dx["Pitcher"] = x["Pitcher"].iloc[0]
    dx["pitcherId"] = i
    dx["team"] = x["team"].iloc[0]
    dx["Hand"] = x["Hand"].iloc[0]
    for pt in list(stuff["PitchType"].unique()):
        if pt in list(x["PitchType"].unique()):
            dx["Stf+ " + pt] = x[x["PitchType"] == pt]["Stuff+"].iloc[0].astype("int64")
            dx[pt + "_ct"] = x[x["PitchType"] == pt]["Count"].iloc[0]
        else:
            dx["Stf+ " + pt] = np.nan
    dx["Total"] = x["Count"].sum()
    rows.append(dx)

# %%
table = pd.DataFrame(rows).reset_index(drop=True)
stf_cols = [col for col in table.columns if col.startswith("Stf+")]
table[stf_cols] = table[stf_cols].astype("Int64")

# Calculating overall Stuff+ based on weighted average of each Stuff+ value. More pitch usage = more weight
table["Stuff+"] = 0.0
for p in pitches:
    col = "Stf+ " + p
    ct_col = p + "_ct"
    if col in table.columns and ct_col in table.columns:
        mask = table[col].notna()
        table.loc[mask, "Stuff+"] += (
            table.loc[mask, col] * (table.loc[mask, ct_col] / table.loc[mask, "Total"])
        )

table["Stuff+"] = table["Stuff+"].round().astype(int)
table = table[["Pitcher", "pitcherId", "team", "Total", "Hand", "Stf+ FA", "Stf+ SL", "Stf+ CU", "Stf+ FC", "Stf+ SI", "Stf+ CH", "Stf+ FS", "Stuff+"]]

# %%
table[table["team"] == "URI"].sort_values("Stuff+", ascending=False)
# Out:
#              Pitcher   pitcherId team  Total Hand  Stf+ FA  Stf+ SL  Stf+ CU  \
# 3201       M. Santos  1487988943  URI    390    R      113      111     <NA>
# 2205       P. Aikens  1299756340  URI    355    L       97      123     <NA>
# 2858       J. Cullen  1358089441  URI    726    R      119      107      106
# 1369   C. Grotyohann  1203468032  URI    296    R      116      101     <NA>
# 513         A. Jones  1101042688  URI    262    R      110      104      109
# 2564      C. Maloney  1336247552  URI    175    R      110      105     <NA>
# 2198        W. Creed  1299086745  URI     68    L      107     <NA>     <NA>
# 579       J. Sabbath  1110853376  URI    768    R      106      110       99
# 2733        B. Perry  1342168540  URI     56    R      104     <NA>     <NA>
# 1227     S. Houchens  1194448803  URI    606    L      105      101     <NA>
# 327       E. Maloney  1085415168  URI    482    R       98       93       90
# ...

# %%
table[table["Total"] >= 500].sort_values("Stuff+", ascending=False).head(10)
# Out:
#           Pitcher   pitcherId  team  Total Hand  Stf+ FA  Stf+ SL  Stf+ CU  \
# 2283   B. Purcell  1307080960   FSU    512    R      128      113     <NA>
# 1287    R. Marohn  1197348608  NCST    638    L      132     <NA>      107
# 4706  D. Volantis  1979617275   TEX   1018    L      102      116      153
# 2217     H. Dietz  1301090561   ARK   1195    L      115      133      142
# 905     G. Helsel  1162012672   XAV    632    L       95      126     <NA>
# 4377   J. Barberi  1862463014   FLA    503    R      131      117     <NA>
# 1296    S. Matson  1198395392   USC    580    L      131      104     <NA>
# 780   L. Peterson  1142994176   FLA   1299    R      125      127      112
# 2024   M. Edwards  1279382784   USC   1264    L      124      113      120
# 3301   W. Sanford  1518897568   ORE   1244    R      126      101      116
#
#       Stf+ FC  Stf+ SI  Stf+ CH  Stf+ FS  Stuff+
# 2283     <NA>     <NA>      138     <NA>     126
# ...

# %%
table[table["Total"] >= 100].sort_values("Stuff+", ascending=False).head(10)
# Out:
#             Pitcher   pitcherId  team  Total Hand  Stf+ FA  Stf+ SL  Stf+ CU  \
# 4688  C. Van Ameyde  1970680555    ND    188    R     <NA>     <NA>     <NA>
# 3415  J. Nottingham  1557710177   UGA    156    R      130     <NA>     <NA>
# 127       C. Powell  1041792638  TXAM    125    L      129     <NA>     <NA>
# 2668       P. Manca  1342167297   FSU    109    L      131      116     <NA>
# 1287      R. Marohn  1197348608  NCST    638    L      132     <NA>      107
# 2283     B. Purcell  1307080960   FSU    512    R      128      113     <NA>
# 4061      N. Helman  1756665469  KENN    420    R      125     <NA>     <NA>
# 2217       H. Dietz  1301090561   ARK   1195    L      115      133      142
# 3140    S. Sandford  1464054215   FLA    312    R      130      112     <NA>
# 4706    D. Volantis  1979617275   TEX   1018    L      102      116      153
#
#       Stf+ FC  Stf+ SI  Stf+ CH  Stf+ FS  Stuff+
# 4688     <NA>      136     <NA>     <NA>     136
# ...

# %%
table[table["Total"] >= 100].sort_values("Stf+ FS", ascending=False).head(10)
# Out:
#            Pitcher   pitcherId  team  Total Hand  Stf+ FA  Stf+ SL  Stf+ CU  \
# 776        J. Noot  1142711296   LSU    124    R       95     <NA>     <NA>
# 2554   J. Giordano  1334554354  RICH    916    L      106      104       98
# 896   L. Earnhardt  1160764160   WIN    871    L      102      100      105
# 626       L. Kenny  1120804043  UOWG    693    R      100      104     <NA>
# 4166      P. Bauer  1791552299   JMU    771    R       95      103       79
# 3417      K. Sweum  1558099259  GONZ   1029    L      112      124     <NA>
# 1389      O. Marsh  1205184939   BEL    328    R       95      102     <NA>
# 182   D. Brousseau  1055997641   BYU    429    R       96     <NA>     <NA>
# 3024      P. Green  1424021277  MIZZ    198    R      109      109     <NA>
# 1271   C. Estridge  1196802304   WVU    404    R      100      101     <NA>
#
#       Stf+ FC  Stf+ SI  Stf+ CH  Stf+ FS  Stuff+
# 776      <NA>      108     <NA>      121     109
# ...

# %%
# Save Stuff+ leaderboard as csv file
table.to_csv("stuff_table.csv")
