# %%
import pandas as pd
import glob

files = glob.glob("pitch_logs/**/*.csv", recursive=True)
df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# Out:
# /var/folders/lr/9t8mdvqx6_58bf8fjvwdbh3h0000gp/T/ipykernel_85085/616367746.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

# %%
del df["Unnamed: 0"]

# %%
len(df)
# Out:
# 5256644

# %%
df.to_csv("full_data.csv")

# %%
x = pd.read_csv("full_data.csv")
len(x)
# Out:
# 5256644

# %%
pd.set_option('display.max_columns', None)
x
# Out:
#          Unnamed: 0  year  pitchingTeamId pitchingTeam  \
# 0                 0  2024       730232064           WM
# 1                 1  2024       730232064           WM
# 2                 2  2024       730232064           WM
# 3                 3  2024       730232064           WM
# 4                 4  2024       730232064           WM
# ...             ...   ...             ...          ...
# 5256639     5256639  2019       730194944          SHU
# 5256640     5256640  2019       730194944          SHU
# 5256641     5256641  2019       730194944          SHU
# 5256642     5256642  2019       730194944          SHU
# 5256643     5256643  2019       730194944          SHU
#
#                               conference  hittingTeamId hittingTeam  \
# 0        D1 Coastal Athletic Association      730187776        CAMP
# 1        D1 Coastal Athletic Association      730187776        CAMP
# 2        D1 Coastal Athletic Association      730187776        CAMP
# ...

# %%
x.sort_values("releaseVelocity", ascending=False).head(25)
# Out:
#          Unnamed: 0  year  pitchingTeamId pitchingTeam  \
# 1515917     1515917  2022       730153728         TENN
# 1515918     1515918  2022       730153728         TENN
# 1515920     1515920  2022       730153728         TENN
# 1487428     1487428  2022       730153728         TENN
# 1515915     1515915  2022       730153728         TENN
# 1515919     1515919  2022       730153728         TENN
# 1487444     1487444  2022       730153728         TENN
# 1487429     1487429  2022       730153728         TENN
# 1515916     1515916  2022       730153728         TENN
# 1487441     1487441  2022       730153728         TENN
# 1527631     1527631  2022       730153728         TENN
# 1515913     1515913  2022       730153728         TENN
# 1487419     1487419  2022       730153728         TENN
# 1487420     1487420  2022       730153728         TENN
# 1487423     1487423  2022       730153728         TENN
# 1487427     1487427  2022       730153728         TENN
# ...

# %%
x[(x["Pitcher"] == "K. Witherspoon") & (x["pitchType"] == "SL")].describe()
# Out:
#          Unnamed: 0         year  pitchingTeamId  hittingTeamId        gameId  \
# count  5.740000e+02   574.000000           574.0   5.740000e+02  5.740000e+02
# mean   1.873234e+06  2024.374564     730294528.0   2.862482e+08  1.381421e+08
# std    8.853605e+05     0.484432             0.0   3.568100e+08  1.859385e+08
# min    6.876640e+05  2024.000000     730294528.0   2.260000e+02  4.525829e+06
# 25%    1.206386e+06  2024.000000     730294528.0   4.806000e+03  4.537335e+06
# 50%    1.979414e+06  2024.000000     730294528.0   5.363000e+03  5.334848e+06
# 75%    2.011838e+06  2025.000000     730294528.0   7.301801e+08  3.493127e+08
# max    5.132615e+06  2025.000000     730294528.0   7.303800e+08  4.988330e+08
#
#            inning       balls     strikes        outs     pitcherId  \
# count  574.000000  574.000000  574.000000  574.000000  5.740000e+02
# mean     3.921603    0.796167    0.836237    1.024390  1.238202e+09
# ...

# %%
x[(x["Pitcher"] == "C. Flukey") & (x["pitchType"] == "FA")].describe()
# Out:
#          Unnamed: 0         year  pitchingTeamId  hittingTeamId        gameId  \
# count  1.268000e+03  1268.000000          1268.0   1.268000e+03  1.268000e+03
# mean   2.852655e+06  2024.642744          4104.0   4.970405e+08  1.664709e+08
# std    1.011352e+06     0.479380             0.0   3.406291e+08  1.407868e+08
# min    5.918000e+03  2024.000000          4104.0   2.320000e+02  4.492095e+06
# 25%    2.884539e+06  2024.000000          4104.0   5.420000e+03  4.538706e+06
# 50%    2.917588e+06  2025.000000          4104.0   7.302403e+08  1.800373e+08
# 75%    3.078651e+06  2025.000000          4104.0   7.303337e+08  2.545631e+08
# max    5.052061e+06  2025.000000          4104.0   7.303805e+08  4.896950e+08
#
#             inning        balls      strikes         outs     pitcherId  \
# count  1268.000000  1268.000000  1268.000000  1268.000000  1.268000e+03
# mean      3.741325     0.915615     0.875394     0.917192  1.238148e+09
# ...

# %%
x[(x["Pitcher"] == "A. Eyanson") & (x["pitchType"] == "SL") & (x["year"] == 2025)].describe()
# Out:
#          Unnamed: 0    year  pitchingTeamId  hittingTeamId        gameId  \
# count  3.880000e+02   388.0           388.0   3.880000e+02  3.880000e+02
# mean   1.729955e+06  2025.0          5323.0   2.503189e+08  3.076426e+08
# std    1.025350e+06     0.0             0.0   3.470498e+08  1.226965e+08
# min    9.037740e+05  2025.0          5323.0   2.450000e+02  1.191682e+08
# 25%    1.180664e+06  2025.0          5323.0   3.375000e+03  2.156200e+08
# 50%    1.240732e+06  2025.0          5323.0   5.048000e+03  3.117797e+08
# 75%    1.900238e+06  2025.0          5323.0   7.302070e+08  4.258634e+08
# max    4.318294e+06  2025.0          5323.0   7.303485e+08  4.775314e+08
#
#            inning       balls     strikes        outs     pitcherId  \
# count  388.000000  388.000000  388.000000  388.000000  3.880000e+02
# mean     3.484536    0.989691    0.984536    0.912371  1.152946e+09
# std      2.071654    1.001238    0.859522    0.775964  0.000000e+00
# ...

# %%
x[x["pitchType"] == "FA"].sort_values("spinRate", ascending=False).head(10)
# Out:
#          Unnamed: 0  year  pitchingTeamId pitchingTeam  \
# 4560876     4560876  2024       730257152          BYU
# 4558349     4558349  2024       730224128         LBSU
# 4369887     4369887  2021            5326          PSU
# 4130241     4130241  2019            1551          MSU
# 2009149     2009149  2024            5342          CMU
# 2320523     2320523  2025       730230272          NKU
# 4907710     4907710  2021       730181888          UNC
# 2777510     2777510  2021       730378496         TROY
# 430251       430251  2022             245          TEX
# 2908103     2908103  2025            4104         CCAR
#
#                            conference  hittingTeamId hittingTeam     gameId  \
# 4560876          D1 Big 12 Conference      730153984         UCD    4526976
# 4558349        D1 Big West Conference      730153984         UCD    4541017
# 4369887         D1 Big Ten Conference      730172928          MD  214375631
# ...

# %%
x.describe()
# Out:
#          Unnamed: 0          year  pitchingTeamId  hittingTeamId  \
# count  5.256644e+06  5.256644e+06    5.256644e+06   5.256644e+06
# mean   2.628322e+06  2.023364e+03    4.499694e+08   4.432143e+08
# std    1.517463e+06  1.590511e+00    3.548223e+08   3.564267e+08
# min    0.000000e+00  2.019000e+03    1.000000e+02   1.000000e+02
# 25%    1.314161e+06  2.022000e+03    5.080000e+03   5.080000e+03
# 50%    2.628322e+06  2.024000e+03    7.301903e+08   7.301842e+08
# 75%    3.942482e+06  2.025000e+03    7.302851e+08   7.302845e+08
# max    5.256643e+06  2.025000e+03    8.021069e+08   7.543153e+08
#
#              gameId        inning         balls       strikes          outs  \
# count  5.256644e+06  5.256644e+06  5.256644e+06  5.256644e+06  5.256644e+06
# mean   2.289479e+08  4.872205e+00  8.976351e-01  8.218689e-01  9.853800e-01
# std    1.620671e+08  2.563687e+00  9.810954e-01  8.171457e-01  8.160032e-01
# ...
